# %%
import pandas
import numpy as np

# %%
# The following is a DataFrame showing monthly Net Operating Income (NOI) of some imagined real estate assets

# The DataFrame is organized with one row per property, and one column per month for each month in 2020 and 2021

# You can assume for this exercise that the data is complete, but the values may be positive or negative

df = pandas.read_csv('sample_df.csv')
df.index = df['Unnamed: 0'].values
df = df.drop(columns='Unnamed: 0')
df
# Out:
#             2020-01-01  2020-02-01  2020-03-01  2020-04-01  2020-05-01  \
# Property A       23083       35157       -4265       -4654       10976
# Property B       -6723        6991        2584       -3622       -1583
# Property C       42150       -1337       -6966       33105       25372
# Property D       46960       12672        8196       24763       35993
# Property E        2478       21201       -5592       28917        5564
# Property F       -9892        6097       39393        8647       31132
# Property G       10020        7719       -5106       40026       -5090
# Property H       46084        2810       32807       26024       -6699
#
#             2020-06-01  2020-07-01  2020-08-01  2020-09-01  2020-10-01  ...  \
# Property A       16702       20167       22477       23543       45211  ...
# Property B       25489       -4522       45589        5576       13409  ...
# Property C        6412        9780       -1772       32078       37706  ...
# ...

# %%
# Calculate the total annual NOI for each property for both 2020 and 2021
# Solution should be a DataFrame with columns for YEAR, PROPERTY NAME, and AVERAGE NOI

# %%
# Calculate the average monthly NOI for each property for both 2020 and 2021 CONSIDERING ONLY POSITIVE MONTHS
# Solution should be a DataFrame with columns for YEAR, PROPERTY NAME, and AVERAGE NOI

# %%
# Create a monthly time-series chart showing the month-over-month change in average NOI for all properties

# %%
df_design = pandas.read_csv('design_matrix.csv').drop(columns='Unnamed: 0')

cols_x = [col for col in df_design.columns if 'noi' not in col]
col_y = 'noi_per_sqft'
df_design
# Out:
#     nooffloors  NATIONAL_RISK_INDEX  FLOODING_RISK_SCORE  POPULATION  \
# 0            1            39.173124            18.577293     5529213
# 1            1            39.318216            21.288636     5952054
# 2            1            16.144807            16.049654     7506908
# 3            1            25.984613            13.245715     2444846
# 4            1            25.984613            13.245715     2445689
# ..         ...                  ...                  ...         ...
# 95           1            38.434642            29.848958     3867266
# 96           1            29.221658             5.660086     2929269
# 97           1            29.221658             5.660086     2914931
# 98           1            26.691771             8.619711     3534145
# 99           1            16.115608             7.312075     6226829
#
#     MEDIAN_HHI  MEDIAN_HV  PCT_UNINSURED  UNEMPLOYMENT_RATE  \
# 0        83160     574094       0.084349           0.073232
# ...

# %%
# Compare models with K-Fold CV using the DataFrame above

# You may use the modeling package of your choice (scikit-learn, pycaret, tensorflow, etc.)

# Choose two different regression models (e.g. Linear Regression and Gradient Boosting Regression) and compare the results of a
# K-Fold CV. 

from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor

X = df_design[cols_x].values
y = df_design[col_y].values
